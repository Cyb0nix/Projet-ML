# %% [markdown]
# # 1. Install Dependencies and Setup

# %%
# !pip install tensorflow opencv-python matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (2.15.0rc1)
# Collecting opencv-python
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/76/9e/4d47a69d3338a00c51535028d25a7d1a17c4762e4a46ae6a577f495de252/opencv_python-4.10.0.82-cp37-abi3-win_amd64.whl.metadata
#   Downloading opencv_python-4.10.0.82-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/c6/c8/6936e8c7b279a5abac82f399d8d72ac25da530cf5f78a0e40063e492558c/matplotlib-3.9.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading matplotlib-3.9.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: tensorflow-intel==2.15.0-rc1 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow) (2.15.0rc1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (68.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0rc0 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0rc0 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorflow-intel==2.15.0-rc1->tensorflow) (2.15.0)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/d6/4f/76d0dd0bca417691918484c26c74dd9dd44fbf528bbfeb30d754886e2c54/contourpy-1.2.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading contourpy-1.2.1-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/00/48/8e9ca9e17de09f5a18d9afb3a3f456689491b985bd144ccc1d9b0c3c06bf/fonttools-4.53.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading fonttools-4.53.0-cp311-cp311-win_amd64.whl.metadata (165 kB)
#      ---------------------------------------- 0.0/165.5 kB ? eta -:--:--
#      ------------------------------------- 165.5/165.5 kB 10.3 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Obtaining dependency information for kiwisolver>=1.3.1 from https://files.pythonhosted.org/packages/1e/37/d3c2d4ba2719059a0f12730947bbe1ad5ee8bff89e8c35319dcb2c9ddb4c/kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Collecting pillow>=8 (from matplotlib)
#   Obtaining dependency information for pillow>=8 from https://files.pythonhosted.org/packages/0a/16/c83877524c47976f16703d2e05c363244bc1e60ab439e078b3cd046d07db/pillow-10.3.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading pillow-10.3.0-cp311-cp311-win_amd64.whl.metadata (9.4 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Obtaining dependency information for pyparsing>=2.3.1 from https://files.pythonhosted.org/packages/9d/ea/6d76df31432a0e6fdf81681a895f009a4bb47b3c39036db3e1b528191d52/pyparsing-3.1.2-py3-none-any.whl.metadata
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0-rc1->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0-rc1->tensorflow) (2.30.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0-rc1->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0-rc1->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0-rc1->tensorflow) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0-rc1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0-rc1->tensorflow) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0-rc1->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0-rc1->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0-rc1->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0-rc1->tensorflow) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0-rc1->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0-rc1->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0-rc1->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0-rc1->tensorflow) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0-rc1->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0-rc1->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\cedri\documents\github\projet-ml\.venv1\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0-rc1->tensorflow) (3.2.2)
# Using cached opencv_python-4.10.0.82-cp37-abi3-win_amd64.whl (38.8 MB)
# Downloading matplotlib-3.9.0-cp311-cp311-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.0 MB 15.4 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/8.0 MB 13.0 MB/s eta 0:00:01
#    ------- -------------------------------- 1.5/8.0 MB 12.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.1/8.0 MB 12.1 MB/s eta 0:00:01
#    ------------- -------------------------- 2.6/8.0 MB 11.9 MB/s eta 0:00:01
#    --------------- ------------------------ 3.1/8.0 MB 11.8 MB/s eta 0:00:01
#    ------------------ --------------------- 3.7/8.0 MB 11.7 MB/s eta 0:00:01
#    --------------------- ------------------ 4.2/8.0 MB 11.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.0 MB 11.6 MB/s eta 0:00:01
#    -------------------------- ------------- 5.3/8.0 MB 11.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.8/8.0 MB 11.6 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.0 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.9/8.0 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------- -- 7.4/8.0 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 11.1 MB/s eta 0:00:00
# Downloading contourpy-1.2.1-cp311-cp311-win_amd64.whl (188 kB)
#    ---------------------------------------- 0.0/188.2 kB ? eta -:--:--
#    --------------------------------------- 188.2/188.2 kB 11.9 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.0-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.2 MB 15.2 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.2 MB 12.9 MB/s eta 0:00:01
#    --------------------------- ------------ 1.5/2.2 MB 12.2 MB/s eta 0:00:01
#    ------------------------------------- -- 2.1/2.2 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 11.7 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB 3.1 MB/s eta 0:00:00
# Downloading pillow-10.3.0-cp311-cp311-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.5 MB 14.2 MB/s eta 0:00:01
#    --------------- ------------------------ 1.0/2.5 MB 12.7 MB/s eta 0:00:01
#    ------------------------ --------------- 1.5/2.5 MB 12.1 MB/s eta 0:00:01
#    -------------------------------- ------- 2.1/2.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.5 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 11.5 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------- 103.2/103.2 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, opencv-python, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.0 kiwisolver-1.4.5 matplotlib-3.9.0 opencv-python-4.10.0.82 pillow-10.3.0 pyparsing-3.1.2
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- --------------
# absl-py                      2.1.0
# anyio                        4.4.0
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    2.4.1
# astunparse                   1.6.3
# async-lru                    2.0.4
# attrs                        23.2.0
# Babel                        2.15.0
# beautifulsoup4               4.12.3
# bleach                       6.1.0
# cachetools                   5.3.3
# certifi                      2024.6.2
# cffi                         1.16.0
# charset-normalizer           3.3.2
# colorama                     0.4.6
# comm                         0.2.2
# contourpy                    1.2.1
# cycler                       0.12.1
# debugpy                      1.8.1
# decorator                    5.1.1
# defusedxml                   0.7.1
# executing                    2.0.1
# fastjsonschema               2.19.1
# flatbuffers                  24.3.25
# fonttools                    4.53.0
# fqdn                         1.5.1
# gast                         0.5.4
# google-auth                  2.30.0
# google-auth-oauthlib         1.2.0
# google-pasta                 0.2.0
# grpcio                       1.64.1
# h11                          0.14.0
# h5py                         3.11.0
# httpcore                     1.0.5
# httpx                        0.27.0
# idna                         3.7
# ipykernel                    6.29.4
# ipython                      8.25.0
# ipywidgets                   8.1.3
# isoduration                  20.11.0
# jedi                         0.19.1
# Jinja2                       3.1.4
# json5                        0.9.25
# jsonpointer                  2.4
# jsonschema                   4.22.0
# jsonschema-specifications    2023.12.1
# jupyter                      1.0.0
# jupyter_client               8.6.2
# jupyter-console              6.6.3
# jupyter_core                 5.7.2
# jupyter-events               0.10.0
# jupyter-lsp                  2.2.5
# jupyter_server               2.14.1
# jupyter_server_terminals     0.5.3
# jupyterlab                   4.2.1
# jupyterlab_pygments          0.3.0
# jupyterlab_server            2.27.2
# jupyterlab_widgets           3.0.11
# keras                        2.15.0
# kiwisolver                   1.4.5
# libclang                     18.1.1
# Markdown                     3.6
# MarkupSafe                   2.1.5
# matplotlib                   3.9.0
# matplotlib-inline            0.1.7
# mistune                      3.0.2
# ml-dtypes                    0.2.0
# nbclient                     0.10.0
# nbconvert                    7.16.4
# nbformat                     5.10.4
# nest-asyncio                 1.6.0
# notebook                     7.2.1
# notebook_shim                0.2.4
# numpy                        1.26.4
# oauthlib                     3.2.2
# opencv-python                4.10.0.82
# opt-einsum                   3.3.0
# overrides                    7.7.0
# packaging                    24.0
# pandocfilters                1.5.1
# parso                        0.8.4
# pillow                       10.3.0
# pip                          23.2.1
# platformdirs                 4.2.2
# prometheus_client            0.20.0
# prompt_toolkit               3.0.46
# protobuf                     4.25.3
# psutil                       5.9.8
# pure-eval                    0.2.2
# pyasn1                       0.6.0
# pyasn1_modules               0.4.0
# pycparser                    2.22
# Pygments                     2.18.0
# pyparsing                    3.1.2
# python-dateutil              2.9.0.post0
# python-json-logger           2.0.7
# pywin32                      306
# pywinpty                     2.0.13
# PyYAML                       6.0.1
# pyzmq                        26.0.3
# qtconsole                    5.5.2
# QtPy                         2.4.1
# referencing                  0.35.1
# requests                     2.32.3
# requests-oauthlib            2.0.0
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rpds-py                      0.18.1
# rsa                          4.9
# Send2Trash                   1.8.3
# setuptools                   68.2.0
# six                          1.16.0
# sniffio                      1.3.1
# soupsieve                    2.5
# stack-data                   0.6.3
# tensorboard                  2.15.2
# tensorboard-data-server      0.7.2
# tensorflow                   2.15.0rc1
# tensorflow-estimator         2.15.0
# tensorflow-intel             2.15.0rc1
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.4.0
# terminado                    0.18.1
# tinycss2                     1.3.0
# tornado                      6.4.1
# traitlets                    5.14.3
# types-python-dateutil        2.9.0.20240316
# typing_extensions            4.12.2
# uri-template                 1.3.0
# urllib3                      2.2.1
# wcwidth                      0.2.13
# webcolors                    24.6.0
# webencodings                 0.5.1
# websocket-client             1.8.0
# Werkzeug                     3.0.3
# wheel                        0.41.2
# widgetsnbextension           4.0.11
# wrapt                        1.14.1
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf
# Out:
# WARNING:tensorflow:From C:\Users\cedri\Documents\GitHub\Projet-ML\.venv1\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %% [markdown]
# # 2. Load Data

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
batch_size = 32
img_height = 256
img_width = 256

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  'data/train',
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1168 files belonging to 6 classes.
# Using 935 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  "data/test",
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 250 files belonging to 6 classes.
# Using 50 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Cirrus', 'Cumulonimbus', 'Cumulus', 'Nimbostratus', 'Stratocumulus', 'Stratus']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # 3. Scale Data

# %%
from tensorflow.keras import layers

normalization_layer = layers.Rescaling(1./255)
# Out:
# WARNING:tensorflow:From C:\Users\cedri\Documents\GitHub\Projet-ML\.venv1\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %% [markdown]
# # 4. Augment Data

# %%
from tensorflow.keras import layers
from tensorflow import keras

data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# # 6. Build Deep Learning Model

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()
num_classes = len(class_names)

# %%
from tensorflow.keras import layers, models

model = models.Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(128, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.2),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes, activation='softmax')  # Assuming multi-class classification
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %% [markdown]
# # 7. Train

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
epochs = 20
history = model.fit(train_ds, epochs=epochs, validation_data=val_ds, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\cedri\Documents\GitHub\Projet-ML\.venv1\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\cedri\Documents\GitHub\Projet-ML\.venv1\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 30/30 [==============================] - 8s 208ms/step - loss: 1.6136 - accuracy: 0.3594 - val_loss: 1.4911 - val_accuracy: 0.4600
# Epoch 2/20
# 30/30 [==============================] - 6s 200ms/step - loss: 1.4671 - accuracy: 0.4257 - val_loss: 1.3404 - val_accuracy: 0.5000
# Epoch 3/20
# 30/30 [==============================] - 6s 197ms/step - loss: 1.3472 - accuracy: 0.4930 - val_loss: 1.2777 - val_accuracy: 0.4800
# Epoch 4/20
# 30/30 [==============================] - 6s 198ms/step - loss: 1.3264 - accuracy: 0.4856 - val_loss: 1.2224 - val_accuracy: 0.5600
# Epoch 5/20
# 30/30 [==============================] - 6s 193ms/step - loss: 1.1610 - accuracy: 0.5316 - val_loss: 1.3067 - val_accuracy: 0.4200
# Epoch 6/20
# 30/30 [==============================] - 6s 193ms/step - loss: 1.0634 - accuracy: 0.6032 - val_loss: 1.4721 - val_accuracy: 0.3400
# Epoch 7/20
# 30/30 [==============================] - 6s 197ms/step - loss: 0.8937 - accuracy: 0.6663 - val_loss: 1.3174 - val_accuracy: 0.4800
# Epoch 8/20
# 30/30 [==============================] - 6s 202ms/step - loss: 0.6836 - accuracy: 0.7561 - val_loss: 1.5126 - val_accuracy: 0.4800
# Epoch 9/20
# 30/30 [==============================] - 6s 198ms/step - loss: 0.5822 - accuracy: 0.7989 - val_loss: 1.3901 - val_accuracy: 0.5200
# Epoch 10/20
# 30/30 [==============================] - 6s 200ms/step - loss: 0.4658 - accuracy: 0.8428 - val_loss: 1.7262 - val_accuracy: 0.4800
# Epoch 11/20
# 30/30 [==============================] - 6s 205ms/step - loss: 0.3638 - accuracy: 0.8888 - val_loss: 1.5063 - val_accuracy: 0.5200
# Epoch 12/20
# 30/30 [==============================] - 6s 208ms/step - loss: 0.3518 - accuracy: 0.8995 - val_loss: 1.7720 - val_accuracy: 0.5200
# Epoch 13/20
# 30/30 [==============================] - 6s 201ms/step - loss: 0.2593 - accuracy: 0.9273 - val_loss: 1.9562 - val_accuracy: 0.5400
# Epoch 14/20
# 30/30 [==============================] - 6s 206ms/step - loss: 0.2429 - accuracy: 0.9294 - val_loss: 1.8189 - val_accuracy: 0.5600
# Epoch 15/20
# 30/30 [==============================] - 7s 224ms/step - loss: 0.1761 - accuracy: 0.9455 - val_loss: 1.9939 - val_accuracy: 0.5200
# Epoch 16/20
# 30/30 [==============================] - 6s 210ms/step - loss: 0.1776 - accuracy: 0.9551 - val_loss: 2.0951 - val_accuracy: 0.5000
# Epoch 17/20
# 30/30 [==============================] - 6s 216ms/step - loss: 0.1531 - accuracy: 0.9658 - val_loss: 1.5309 - val_accuracy: 0.6800
# Epoch 18/20
# 30/30 [==============================] - 7s 234ms/step - loss: 0.1398 - accuracy: 0.9647 - val_loss: 1.9505 - val_accuracy: 0.5800
# Epoch 19/20
# 30/30 [==============================] - 7s 240ms/step - loss: 0.1481 - accuracy: 0.9636 - val_loss: 1.5985 - val_accuracy: 0.6400
# Epoch 20/20
# 30/30 [==============================] - 7s 237ms/step - loss: 0.1186 - accuracy: 0.9711 - val_loss: 1.5478 - val_accuracy: 0.5800

# %% [markdown]
# # 8. Plot Performance

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # 9. Evaluate

# %%
from keras.src.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
print(pre.result(), re.result(), acc.result())
# Out:
# tf.Tensor(0.0, shape=(), dtype=float32) tf.Tensor(0.0, shape=(), dtype=float32) tf.Tensor(0.0, shape=(), dtype=float32)

# %% [markdown]
# # 10. Test

# %%
test_image = 'Cirrocumulus_undulatus_in_various_directions.jpeg'

# %%
img = tf.keras.utils.load_img(
    test_image, target_size=(img_height, img_width)
)

# %%
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

# %%
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])
# Out:
# 1/1 [==============================] - 0s 140ms/step

# %%
print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to Cirrus with a 34.33 percent confidence.

# %% [markdown]
# # 11. Save the Model

# %%
# Save the model as a SavedModel
model.export('models/cloudclassifier')

# Convert the SavedModel to TensorFlow.js format
converter = tf.lite.TFLiteConverter.from_saved_model('models/cloudclassifier')
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS]

try:
  tflite_model = converter.convert()
  with open('models/cloudclassifier.tfjs', 'wb') as f:
    f.write(tflite_model)
  print("Model converted and saved to models/cloudclassifier.tfjs")
except Exception as e:
  print("Conversion failed:", e)
# Out:
# INFO:tensorflow:Assets written to: models/cloudclassifier\assets
# INFO:tensorflow:Assets written to: models/cloudclassifier\assets
# Saved artifact at 'models/cloudclassifier'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='rescaling_2_input')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   2455815975568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2454592347152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2454592343312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2454592347728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2454592348304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2454592348880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2454592347920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2454592349264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2454592348496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2454592349456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2454592346960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2454592349840: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model converted and saved to models/cloudclassifier.tfjs
